# %%
import json
import pandas as pd

# %%
FOLDER = "./data/"

# %%
with open(FOLDER+"ugcContributions.json") as f:
    contribData = json.load(f)
contribData
# Out:
# {'itMakesMeFeel_emotions': {'HoNIcWZY': [{'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'e4aM9WL7': [{'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'bSuOYLw2': [{'id': '6338649a2df2fd104d686349',
#     'userid': 'bSuOYLw2',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338649a2df2fd104d686349',
#     'userid': 'bSuOYLw2',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cmq6JZxJ': [{'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'BTKF72et': [{'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 0.92910606},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Serenity': 0.97778475},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '35224',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 0.96569455},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'fqybaAk8': [{'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35217',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'PxrTX0Ln': [{'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Surprise': 1.97407156},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'anqHwMQ0': [{'id': '6228777680271c3692478fc0',
#     'userid': 'anqHwMQ0',
#     'origin': '35412',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6228777680271c3692478fc0',
#     'userid': 'anqHwMQ0',
#     'origin': '39352',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'yjlouq5U': [{'id': '63385bb4f5bdab798a1a88a3',
#     'userid': 'yjlouq5U',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4f5bdab798a1a88a3',
#     'userid': 'yjlouq5U',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '6rK3p7za': [{'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '35450',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '35208',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'RQ4a2nIG': [{'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'ox8G7avH': [{'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35465',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35256',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Anticipation': 1.0, 'Surprise': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35249',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '0bAAwK14': [{'id': '63313e7848ebba445a3b3cee',
#     'userid': '0bAAwK14',
#     'origin': '35450',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 1.9481361499999998},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63313e7848ebba445a3b3cee',
#     'userid': '0bAAwK14',
#     'origin': '35215',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 1.94494486},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'KQTGApjD': [{'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 1.9905802000000001},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'loEoYm9R': [{'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2GROTNeg': [{'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 1.9596841299999999, 'Serenity': 1.9382869999999999},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'ZWrgWx9o': [{'id': '63382d748ceb081caa6ba997',
#     'userid': 'ZWrgWx9o',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63382d748ceb081caa6ba997',
#     'userid': 'ZWrgWx9o',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'BNtsz8zb': [{'id': '6364f4427777834a837dc841',
#     'userid': 'BNtsz8zb',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4427777834a837dc841',
#     'userid': 'BNtsz8zb',
#     'origin': '35217',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oITaD0ND': [{'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '39384',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'lkkZ1lUv': [{'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Y0WXF1LR': [{'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'SIbOTAP7': [{'id': '63a32d7079c711024c352232',
#     'userid': 'SIbOTAP7',
#     'origin': '39426',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a32d7079c711024c352232',
#     'userid': 'SIbOTAP7',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2LIm9lcH': [{'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35374',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '3K9AMmqU': [{'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35374',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35222',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'xi3DCToA': [{'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35307',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'eLXgq0Hx': [{'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Anticipation': 1.8508643500000002},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '39389',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 1.5481556699999999},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Q13Gnsty': [{'id': '63a58223d959850727603dd4',
#     'userid': 'Q13Gnsty',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a58223d959850727603dd4',
#     'userid': 'Q13Gnsty',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Trust': 0.76917523, 'Interest': 1.0, 'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'NROrO0c9': [{'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'W7Wnqxw4': [{'id': '6364f37340b32d50317c6f22',
#     'userid': 'W7Wnqxw4',
#     'origin': '35321',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f37340b32d50317c6f22',
#     'userid': 'W7Wnqxw4',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '8sAIqaGe': [{'id': '633865ce947d991ed04cf7dc',
#     'userid': '8sAIqaGe',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633865ce947d991ed04cf7dc',
#     'userid': '8sAIqaGe',
#     'origin': '35215',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'gD630RD1': [{'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Bf5Sj3ON': [{'id': '6364f52f2d082603e158e7b1',
#     'userid': 'Bf5Sj3ON',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f52f2d082603e158e7b1',
#     'userid': 'Bf5Sj3ON',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'jTb1qXEo': [{'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35321',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35208',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'x2AUnHqw': [{'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'GV4z5ANK': [{'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'N72IRgFy': [{'id': '63384f412899916df970879f',
#     'userid': 'N72IRgFy',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384f412899916df970879f',
#     'userid': 'N72IRgFy',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Wsip5y7A': [{'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '39182',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'sXKZ1IUH': [{'id': '636d08475e7e496bb86b67a1',
#     'userid': 'sXKZ1IUH',
#     'origin': '39182',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Surprise': 1.9455653000000002, 'Trust': 1.9214504},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636d08475e7e496bb86b67a1',
#     'userid': 'sXKZ1IUH',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 0.7172852, 'Serenity': 2.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'btoSxy3T': [{'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'R4frFK0J': [{'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'B3N0HGw4': [{'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 1.9596841299999999, 'Serenity': 1.9382869999999999},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'q2BDj1os': [{'id': '63383ea41c952b2c5e786acf',
#     'userid': 'q2BDj1os',
#     'origin': '39384',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63383ea41c952b2c5e786acf',
#     'userid': 'q2BDj1os',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'EEm3fSZd': [{'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35222',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WYCImqGm': [{'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Sz5Wx2XD': [{'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'JgevtrSb': [{'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'GdMZ5rXI': [{'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FQFaM9D4': [{'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 1.7947365},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Surprise': 1.0, 'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'M38rC6wd': [{'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35307',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LvIeXwcT': [{'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Sadness': 1.7683326, 'Serenity': 1.9850386},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Trust': 0.76917523, 'Interest': 1.0, 'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'zZbRbDHJ': [{'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'V337a5b8': [{'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Disapproval': 0.60135823, 'Sadness': 0.89056844},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WsK2A1ab': [{'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39352',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35412',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2JfmseEG': [{'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FVhf7OMw': [{'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {'Joy': 0.79744923},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35225',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '7zL8hKS8': [{'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cBjFhvjx': [{'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LW3Klzvx': [{'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39427',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FbEHiNmP': [{'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'onDqgFnI': [{'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeFeel.emotions',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
# ...
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63383ea41c952b2c5e786acf',
#     'userid': 'q2BDj1os',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'EEm3fSZd': [{'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35222',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WYCImqGm': [{'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Sz5Wx2XD': [{'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'JgevtrSb': [{'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {'Positive': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {'Positive': 1.87465626},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'GdMZ5rXI': [{'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FQFaM9D4': [{'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {'Positive': 0.5337253},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'M38rC6wd': [{'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35307',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LvIeXwcT': [{'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {'Positive': 0.78760004},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': {'Positive': 0.9073386},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'zZbRbDHJ': [{'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'V337a5b8': [{'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WsK2A1ab': [{'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39352',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35412',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2JfmseEG': [{'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FVhf7OMw': [{'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35225',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '7zL8hKS8': [{'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cBjFhvjx': [{'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LW3Klzvx': [{'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39427',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FbEHiNmP': [{'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'onDqgFnI': [{'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oTT3YRMN': [{'id': '6364f959ec3ec867f01140fb',
#     'userid': 'oTT3YRMN',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f959ec3ec867f01140fb',
#     'userid': 'oTT3YRMN',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itRemindsMeOf.sentiment',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}]}}

# %%
suffix = ["_emotions", "_sentiment", "_text"]
prefix = ["itMakesMeFeel", "itRemindsMeOf", "itMakesMeThinkAbout"]

# %% [markdown]
# # Join dataframes

# %%
def createDataframe(dfname):
    """Creates a dataframe using the data
    in contribData below the key dfname
    """
    data = []
    for user in contribData[dfname]:    
        data.extend(contribData[dfname][user])
    df = pd.DataFrame(data)
    df['pvalue'] = df['pvalue'].apply(lambda v: {} if (v=='') else v)
    return df

# %%
dataframes = {}
for p in prefix:
    for s in suffix:
        name = p+s
        dataframes[name] = createDataframe(name)

# %%
def joinDict(d1,d2):
    """
    Joins two dictionaries. If dictionaries have the same key, then values are merged in a list
    """
    joined = {}
    keys = set(d1.keys()).union(set(d2.keys()))
    for key in keys:
        if key in d1:            
            if key in d2:
                if type(d1[key])==list:
                    d1[key].append(d2[key])
                    joined[key] = d1[key]
                else:
                    joined[key] = [d1[key],d2[key]]
            else: # key in d1 but not in d2
                # If the value is a list then remains as a list, else creates a list with this value.
                joined[key] = d1[key] if type(d1[key])==list else [d1[key]]
        else: # key not in d1
            # If the value is a list then remains as a list, else creates a list with this value.
            joined[key] = d2[key] if type(d2[key])==list else [d2[key]]
    return joined

# %%
def joinDataframes( aDfList , joinFunction = joinDict):
    """
    Joins a list of dataframes using userid and origin
    A joinFunction is employed to merge the pvalues of sucessive joins. The result of all these joins
    are stored in "agg_pvalue"
    """
    assert(len(aDfList)>0)
    columns = ["id","userid","origin","pname","pvalue"]
    if len(aDfList) >= 2:
        # First pass: merge the first two dataframes and creates the "agg_pvalue"
        i=1
        join = pd.merge(aDfList[i-1][columns],aDfList[i][columns],on=["userid","origin"], suffixes=(f'_{i-1}',f'_{i}'), how="outer")  
        join["agg_pvalue"]=join.apply(lambda row: joinFunction(row[f'pvalue_{i-1}'], row[f'pvalue_{i}']), axis=1)
        i+=1
        while i<len(aDfList):
            # Succesive dataframes are merged into "agg_pvalue"
            join = pd.merge(join,aDfList[i][columns],on=["userid","origin"], suffixes=(f'_{i-1}',f'_{i}'), how="outer")
            join.rename(columns={"pname": f'pname_{i}', "pvalue": f'pvalue_{i}'}, inplace=True)
            join["agg_pvalue"]=join.apply(lambda row: joinFunction(row["agg_pvalue"], row[f'pvalue_{i}']), axis=1)
            i+=1
        return join            
    else:
        return aDfList[0]

# %%
def avgForKeys(aDict):
    """Transforms all the list values in a dictionary to a single value that represents
    the average value of the list 
    """
    newDict = {}
    for key in aDict:
        if aDict[key] != None:
            if len(aDict[key]) == 1:
                newDict[key] = aDict[key][0]
            else:
                newDict[key] = sum(aDict[key])/len(aDict[key])
    return newDict

# %% [markdown]
# ## Emotions

# %%
# Create the aggregated dataframe for emotions
dfToJoin = [dataframes[p+"_emotions"] for p in prefix]
dfEmotions = joinDataframes(dfToJoin)

# %%
dfEmotions["agg_pvalue"] = dfEmotions["agg_pvalue"].apply(avgForKeys)
dfEmotions["agg_pvalue"].value_counts()
# Out:
# {}                                                                                        90
# {'Joy': 1.0}                                                                               5
# {'Fear': 1.0}                                                                              3
# {'Sadness': 1.0}                                                                           3
# {'Serenity': 1.0}                                                                          3
#                                                                                           ..
# {'Sadness': 1.0, 'Disapproval': 1.0, 'Anger': 1.0, 'Anticipation': 1.8508643500000002}     1
# {'Sadness': 1.5602488}                                                                     1
# {'Sadness': 1.0, 'Trust': 0.76917523, 'Interest': 1.0, 'Joy': 0.73672265}                  1
# {'Joy': 1.0, 'Serenity': 1.0}                                                              1
# {'Disapproval': 0.60185623, 'Love': 2.0}                                                   1
# Name: agg_pvalue, Length: 68, dtype: int64

# %%
cleanContrib = dfEmotions[(dfEmotions["agg_pvalue"]!={}) & (dfEmotions["agg_pvalue"]!={'False': 1.0}) ]
len(cleanContrib)
# Out:
# 85

# %%
len(cleanContrib["userid"].unique())
# Out:
# 48

# %%
len(cleanContrib["origin"].unique())
# Out:
# 41

# %%
#pd.set_option('display.max_rows', None)
dfEmotions
# Out:
#                          id_0    userid origin                 pname_0  \
# 0    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35330  itMakesMeFeel.emotions
# 1    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35229  itMakesMeFeel.emotions
# 2    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35380  itMakesMeFeel.emotions
# 3    622764d6efc0335e1948a813  e4aM9WL7  35229  itMakesMeFeel.emotions
# 4    622764d6efc0335e1948a813  e4aM9WL7  39175  itMakesMeFeel.emotions
# ..                        ...       ...    ...                     ...
# 170  633856a77043f23cb5236441  onDqgFnI  35362  itMakesMeFeel.emotions
# 171  633856a77043f23cb5236441  onDqgFnI  39416  itMakesMeFeel.emotions
# 172  633856a77043f23cb5236441  onDqgFnI  35229  itMakesMeFeel.emotions
# 173  6364f959ec3ec867f01140fb  oTT3YRMN  35364  itMakesMeFeel.emotions
# 174  6364f959ec3ec867f01140fb  oTT3YRMN  35230  itMakesMeFeel.emotions
#
#     pvalue_0                      id_1                 pname_1  \
# 0         {}  6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.emotions
# 1         {}  6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.emotions
# 2         {}  6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.emotions
# 3         {}  622764d6efc0335e1948a813  itRemindsMeOf.emotions
# 4         {}  622764d6efc0335e1948a813  itRemindsMeOf.emotions
# ..       ...                       ...                     ...
# 170       {}  633856a77043f23cb5236441  itRemindsMeOf.emotions
# 171       {}  633856a77043f23cb5236441  itRemindsMeOf.emotions
# 172       {}  633856a77043f23cb5236441  itRemindsMeOf.emotions
# 173       {}  6364f959ec3ec867f01140fb  itRemindsMeOf.emotions
# 174       {}  6364f959ec3ec867f01140fb  itRemindsMeOf.emotions
#
#                pvalue_1                                agg_pvalue  \
# 0                    {}                     {'Anticipation': 1.0}
# 1                    {}                                        {}
# 2                    {}                                        {}
# 3    {'Joy': 1.6366995}                        {'Joy': 1.6366995}
# 4                    {}                                        {}
# ..                  ...                                       ...
# 170                  {}                                        {}
# 171                  {}                                        {}
# 172                  {}                                        {}
# 173                  {}                        {'Joy': 0.6227641}
# 174                  {}  {'Disapproval': 0.60185623, 'Love': 2.0}
#
#                            id                       pname_2  \
# 0    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.emotions
# 1    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.emotions
# 2    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.emotions
# 3    622764d6efc0335e1948a813  itMakesMeThinkAbout.emotions
# 4    622764d6efc0335e1948a813  itMakesMeThinkAbout.emotions
# ..                        ...                           ...
# 170  633856a77043f23cb5236441  itMakesMeThinkAbout.emotions
# 171  633856a77043f23cb5236441  itMakesMeThinkAbout.emotions
# 172  633856a77043f23cb5236441  itMakesMeThinkAbout.emotions
# 173  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.emotions
# 174  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.emotions
#
#                                      pvalue_2
# 0                       {'Anticipation': 1.0}
# 1                                          {}
# 2                                          {}
# 3                                          {}
# 4                                          {}
# ..                                        ...
# 170                                        {}
# 171                                        {}
# 172                                        {}
# 173                        {'Joy': 0.6227641}
# 174  {'Disapproval': 0.60185623, 'Love': 2.0}
#
# [175 rows x 12 columns]

# %% [markdown]
# ## Sentiment

# %%
# Create the aggregated dataframe for sentiment
dfToJoin = [dataframes[p+"_sentiment"] for p in prefix]
dfSentiment = joinDataframes(dfToJoin)

# %%
dfSentiment["agg_pvalue"] = dfSentiment["agg_pvalue"].apply(avgForKeys)
dfSentiment["agg_pvalue"].value_counts()
# Out:
# {}                                      50
# {'Positive': 0.7475769}                  8
# {'Neutral': 1}                           6
# {'Positive': 1.0}                        6
# {'Positive': 1.0312800500000001}         4
#                                         ..
# {'Positive': 0.9855656}                  1
# {'Positive': 1.92746556}                 1
# {'Positive': 0.926056, 'Neutral': 1}     1
# {'Positive': 0.91901934}                 1
# {'Positive': 1.6187261}                  1
# Name: agg_pvalue, Length: 99, dtype: int64

# %%
def joinString (s1, s2):
    """Joins two strings (ignoring empty strings)
    """
    s1 = "" if s1 == {} else s1
    s2 = "" if s2 == {} else s2
    if s1 == "":
        if s2 == "":
            return ""
        else:
            return s2
    else:
        if s2 == "":
            return s1
        else:
            return s1+", "+s2

# %% [markdown]
# ## Text

# %%
# Create the aggregated dataframe for the texts        
dfToJoin = [dataframes[p+"_text"] for p in prefix]
dfText = joinDataframes(dfToJoin, joinString)

# %%
#pd.set_option('display.max_rows', None)
#dfText['agg_pvalue'] = dfText['agg_pvalue'].apply(lambda text: text.encode("ascii", "ignore").decode())
dfText
# Out:
#                          id_0    userid origin             pname_0 pvalue_0  \
# 0    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35330  itMakesMeFeel.text       {}
# 1    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35229  itMakesMeFeel.text       {}
# 2    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35380  itMakesMeFeel.text       {}
# 3    622764d6efc0335e1948a813  e4aM9WL7  35229  itMakesMeFeel.text       {}
# 4    622764d6efc0335e1948a813  e4aM9WL7  39175  itMakesMeFeel.text       {}
# ..                        ...       ...    ...                 ...      ...
# 170  633856a77043f23cb5236441  onDqgFnI  35362  itMakesMeFeel.text       {}
# 171  633856a77043f23cb5236441  onDqgFnI  39416  itMakesMeFeel.text       {}
# 172  633856a77043f23cb5236441  onDqgFnI  35229  itMakesMeFeel.text       {}
# 173  6364f959ec3ec867f01140fb  oTT3YRMN  35364  itMakesMeFeel.text       {}
# 174  6364f959ec3ec867f01140fb  oTT3YRMN  35230  itMakesMeFeel.text       {}
#
#                          id_1             pname_1     pvalue_1  \
# 0    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 1    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 2    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 3    622764d6efc0335e1948a813  itRemindsMeOf.text  al mare\n\n
# 4    622764d6efc0335e1948a813  itRemindsMeOf.text   malattia\n
# ..                        ...                 ...          ...
# 170  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 171  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 172  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 173  6364f959ec3ec867f01140fb  itRemindsMeOf.text           {}
# 174  6364f959ec3ec867f01140fb  itRemindsMeOf.text           {}
#
#                                             agg_pvalue  \
# 0                                          Prospettive
# 1                                        Mondi diversi
# 2                                      (forse) Onirici
# 3                                          al mare\n\n
# 4                                           malattia\n
# ..                                                 ...
# 170
# 171
# 172
# 173  mia mamma perché è grazie a lei ed ai suoi ins...
# 174  l’amore perché dalla mia ragazza mi sento vera...
#
#                            id                   pname_2  \
# 0    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 1    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 2    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 3    622764d6efc0335e1948a813  itMakesMeThinkAbout.text
# 4    622764d6efc0335e1948a813  itMakesMeThinkAbout.text
# ..                        ...                       ...
# 170  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 171  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 172  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 173  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.text
# 174  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.text
#
#                                               pvalue_2
# 0                                          Prospettive
# 1                                        Mondi diversi
# 2                                      (forse) Onirici
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 170                                                 {}
# 171                                                 {}
# 172                                                 {}
# 173  mia mamma perché è grazie a lei ed ai suoi ins...
# 174  l’amore perché dalla mia ragazza mi sento vera...
#
# [175 rows x 12 columns]

# %%
dfText
# Out:
#                          id_0    userid origin             pname_0 pvalue_0  \
# 0    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35330  itMakesMeFeel.text       {}
# 1    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35229  itMakesMeFeel.text       {}
# 2    6364f4e9ad16cc2ce70b6f0f  HoNIcWZY  35380  itMakesMeFeel.text       {}
# 3    622764d6efc0335e1948a813  e4aM9WL7  35229  itMakesMeFeel.text       {}
# 4    622764d6efc0335e1948a813  e4aM9WL7  39175  itMakesMeFeel.text       {}
# ..                        ...       ...    ...                 ...      ...
# 170  633856a77043f23cb5236441  onDqgFnI  35362  itMakesMeFeel.text       {}
# 171  633856a77043f23cb5236441  onDqgFnI  39416  itMakesMeFeel.text       {}
# 172  633856a77043f23cb5236441  onDqgFnI  35229  itMakesMeFeel.text       {}
# 173  6364f959ec3ec867f01140fb  oTT3YRMN  35364  itMakesMeFeel.text       {}
# 174  6364f959ec3ec867f01140fb  oTT3YRMN  35230  itMakesMeFeel.text       {}
#
#                          id_1             pname_1     pvalue_1  \
# 0    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 1    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 2    6364f4e9ad16cc2ce70b6f0f  itRemindsMeOf.text           {}
# 3    622764d6efc0335e1948a813  itRemindsMeOf.text  al mare\n\n
# 4    622764d6efc0335e1948a813  itRemindsMeOf.text   malattia\n
# ..                        ...                 ...          ...
# 170  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 171  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 172  633856a77043f23cb5236441  itRemindsMeOf.text           {}
# 173  6364f959ec3ec867f01140fb  itRemindsMeOf.text           {}
# 174  6364f959ec3ec867f01140fb  itRemindsMeOf.text           {}
#
#                                             agg_pvalue  \
# 0                                          Prospettive
# 1                                        Mondi diversi
# 2                                      (forse) Onirici
# 3                                          al mare\n\n
# 4                                           malattia\n
# ..                                                 ...
# 170
# 171
# 172
# 173  mia mamma perché è grazie a lei ed ai suoi ins...
# 174  l’amore perché dalla mia ragazza mi sento vera...
#
#                            id                   pname_2  \
# 0    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 1    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 2    6364f4e9ad16cc2ce70b6f0f  itMakesMeThinkAbout.text
# 3    622764d6efc0335e1948a813  itMakesMeThinkAbout.text
# 4    622764d6efc0335e1948a813  itMakesMeThinkAbout.text
# ..                        ...                       ...
# 170  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 171  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 172  633856a77043f23cb5236441  itMakesMeThinkAbout.text
# 173  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.text
# 174  6364f959ec3ec867f01140fb  itMakesMeThinkAbout.text
#
#                                               pvalue_2
# 0                                          Prospettive
# 1                                        Mondi diversi
# 2                                      (forse) Onirici
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 170                                                 {}
# 171                                                 {}
# 172                                                 {}
# 173  mia mamma perché è grazie a lei ed ai suoi ins...
# 174  l’amore perché dalla mia ragazza mi sento vera...
#
# [175 rows x 12 columns]

# %% [markdown]
# # Store in a JSON file

# %%
template = {
    'id': None,
    'userid': None,
    'origin': None,
    'source_id': 'fake90e6d701748f08514b01',
    'source': 'fake',
    'pname': None,
    'pvalue': None,
    'context': 'application',
    'datapoints': 0,
    'category': 'interest'
}

# %%
def createObject (rowData, template, pname):
    """Creates an object using a template according to data in rowData.
    """
    newObject = template.copy()
    newObject['id'] = rowData['id']
    newObject['userid'] = rowData['userid']
    newObject['origin'] = rowData['origin']
    newObject['pname'] = pname
    newObject['pvalue'] = rowData['agg_pvalue']
    return newObject

def addObjectToList (userid, dataFrame, rowIndexList, template, pname):
    """Creates a list of objects according to the information stored in a dataframe
    """
    aList = []
    for row in rowIndexList:
        # rowIndexList is a list of valid indexes in dataFrame
        newObject = createObject(dataFrame.loc[row],template,pname)
        aList.append(newObject)
    return aList


# Uncomment this line to see the structure of a Pandas Groupby
# (a dict where keys are userids and values are list of index values)
#dfEmotions.groupby(by=["userid"]).groups

# %%
newContribData = {
    'itMakesMeThinkAbout_emotions' : {},
    'itMakesMeThinkAbout_sentiment' : {},
    'itMakesMeThinkAbout_text' : {},
}
for userid, rowIndexList in dfEmotions.groupby(by=["userid"]).groups.items():
    contribList = addObjectToList (userid, dfEmotions, rowIndexList, template, 'itMakesMeThinkAbout.emotions')
    newContribData['itMakesMeThinkAbout_emotions'][userid] = contribList

for userid, rowIndexList in dfSentiment.groupby(by=["userid"]).groups.items():
    contribList = addObjectToList (userid, dfSentiment, rowIndexList, template, 'itMakesMeThinkAbout.sentiment')
    newContribData['itMakesMeThinkAbout_sentiment'][userid] = contribList

for userid, rowIndexList in dfText.groupby(by=["userid"]).groups.items():
    contribList = addObjectToList (userid, dfText, rowIndexList, template, 'itMakesMeThinkAbout.text')
    newContribData['itMakesMeThinkAbout_text'][userid] = contribList

newContribData
# Out:
# {'itMakesMeThinkAbout_emotions': {'0bAAwK14': [{'id': '63313e7848ebba445a3b3cee',
#     'userid': '0bAAwK14',
#     'origin': '35450',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 2.407580425, 'Interest': 1.0, 'Joy': 0.8233193},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63313e7848ebba445a3b3cee',
#     'userid': '0bAAwK14',
#     'origin': '35215',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.767029006666667},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2GROTNeg': [{'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.9596841299999999, 'Serenity': 1.9382869999999999},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a3248b88aacc4c1b0e3069',
#     'userid': '2GROTNeg',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2JfmseEG': [{'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 2.0, 'Trust': 1.0, 'Surprise': 1.0, 'Anticipation': 2.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.55502737},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f236b6342028c320ac96',
#     'userid': '2JfmseEG',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '2LIm9lcH': [{'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Love': 1.96113384},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '35374',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Trust': 0.85408616},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '637ba86a5fe06708aa2277c7',
#     'userid': '2LIm9lcH',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '3K9AMmqU': [{'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.9954855},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35374',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.9673313},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2f0e3da80744e7cfe2d',
#     'userid': '3K9AMmqU',
#     'origin': '35222',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '6rK3p7za': [{'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '35450',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 0.69059783, 'Sadness': 0.6233554, 'Joy': 0.65415454},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '35208',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6333fc6b8975311483239877',
#     'userid': '6rK3p7za',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '7zL8hKS8': [{'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f27c39a6d246b2029ad9',
#     'userid': '7zL8hKS8',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   '8sAIqaGe': [{'id': '633865ce947d991ed04cf7dc',
#     'userid': '8sAIqaGe',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633865ce947d991ed04cf7dc',
#     'userid': '8sAIqaGe',
#     'origin': '35215',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0, 'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'B3N0HGw4': [{'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.9596841299999999, 'Serenity': 1.9382869999999999},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633858f82b631c1bf17add1d',
#     'userid': 'B3N0HGw4',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'BNtsz8zb': [{'id': '6364f4427777834a837dc841',
#     'userid': 'BNtsz8zb',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4427777834a837dc841',
#     'userid': 'BNtsz8zb',
#     'origin': '35217',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.8936893},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'BTKF72et': [{'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.92910606},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 0.796984675},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '632dab3fcfb08e51f124bcef',
#     'userid': 'BTKF72et',
#     'origin': '35224',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.96569455},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Bf5Sj3ON': [{'id': '6364f52f2d082603e158e7b1',
#     'userid': 'Bf5Sj3ON',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7643106, 'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f52f2d082603e158e7b1',
#     'userid': 'Bf5Sj3ON',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.9152404, 'Disgust': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'EEm3fSZd': [{'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f036c4281001195d2ea2',
#     'userid': 'EEm3fSZd',
#     'origin': '35222',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FQFaM9D4': [{'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7947365, 'Trust': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a5810e4af3b814e41df892',
#     'userid': 'FQFaM9D4',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Surprise': 1.0, 'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FVhf7OMw': [{'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.79744923},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4be73e50c31468039',
#     'userid': 'FVhf7OMw',
#     'origin': '35225',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'FbEHiNmP': [{'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.8428114},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31dc8360026478a5827b5',
#     'userid': 'FbEHiNmP',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'GV4z5ANK': [{'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f2c21215e37ae0724125',
#     'userid': 'GV4z5ANK',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'GdMZ5rXI': [{'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a32f4b00d7676f1d2d8825',
#     'userid': 'GdMZ5rXI',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'HoNIcWZY': [{'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f4e9ad16cc2ce70b6f0f',
#     'userid': 'HoNIcWZY',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'JgevtrSb': [{'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0, 'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636cc9262ccec113b95079bf',
#     'userid': 'JgevtrSb',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.82976425, 'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'KQTGApjD': [{'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.9905802000000001},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857981931f9059341ba94',
#     'userid': 'KQTGApjD',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LW3Klzvx': [{'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Trust': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '39427',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.8110314, 'Surprise': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338593d2b631c1bf17add24',
#     'userid': 'LW3Klzvx',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'LvIeXwcT': [{'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.7683326, 'Serenity': 1.98919085},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0,
#      'Trust': 0.76917523,
#      'Interest': 1.0,
#      'Joy': 0.5629748},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63370e3a45ee936df82d4d06',
#     'userid': 'LvIeXwcT',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'M38rC6wd': [{'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35307',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '635aad1d10d4dc16491ed007',
#     'userid': 'M38rC6wd',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'N72IRgFy': [{'id': '63384f412899916df970879f',
#     'userid': 'N72IRgFy',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384f412899916df970879f',
#     'userid': 'N72IRgFy',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'NROrO0c9': [{'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3a16da83f3b9e498b10',
#     'userid': 'NROrO0c9',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'PxrTX0Ln': [{'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Surprise': 1.97407156},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f352e5a2fa0ed0297d0f',
#     'userid': 'PxrTX0Ln',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Love': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Q13Gnsty': [{'id': '63a58223d959850727603dd4',
#     'userid': 'Q13Gnsty',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.5602488},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a58223d959850727603dd4',
#     'userid': 'Q13Gnsty',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0,
#      'Trust': 0.76917523,
#      'Interest': 1.0,
#      'Joy': 0.73672265},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'R4frFK0J': [{'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Surprise': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f3d239a6d246b2029afb',
#     'userid': 'R4frFK0J',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'RQ4a2nIG': [{'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7501367349999999, 'Serenity': 0.72991085},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7501367349999999,
#      'Interest': 1.0,
#      'Serenity': 0.72991085},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 2.0, 'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7501367349999999, 'Serenity': 0.72991085},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.7501367349999999,
#      'Interest': 1.0,
#      'Serenity': 0.72991085},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633869df947d991ed04cf7f7',
#     'userid': 'RQ4a2nIG',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 2.0, 'Interest': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'SIbOTAP7': [{'id': '63a32d7079c711024c352232',
#     'userid': 'SIbOTAP7',
#     'origin': '39426',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a32d7079c711024c352232',
#     'userid': 'SIbOTAP7',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Sz5Wx2XD': [{'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Trust': 0.52022713},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338625f758e693b2f1aea9d',
#     'userid': 'Sz5Wx2XD',
#     'origin': '35245',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 0.9373044},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'V337a5b8': [{'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.89056844, 'Disapproval': 0.60135823},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f54639a6d246b2029b07',
#     'userid': 'V337a5b8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.98838043},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'W7Wnqxw4': [{'id': '6364f37340b32d50317c6f22',
#     'userid': 'W7Wnqxw4',
#     'origin': '35321',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f37340b32d50317c6f22',
#     'userid': 'W7Wnqxw4',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WYCImqGm': [{'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338483ddf44765455526ee4',
#     'userid': 'WYCImqGm',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'WsK2A1ab': [{'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35221',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39352',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 0.63115853},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.95738137, 'Anticipation': 1.9017547000000001},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338389e48506113dc315697',
#     'userid': 'WsK2A1ab',
#     'origin': '35412',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Wsip5y7A': [{'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '39182',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 0.52267414},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a317d1360026478a582765',
#     'userid': 'Wsip5y7A',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'Y0WXF1LR': [{'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 0.67041326},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35288',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385c0def7ec10976083ec4',
#     'userid': 'Y0WXF1LR',
#     'origin': '35323',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'ZWrgWx9o': [{'id': '63382d748ceb081caa6ba997',
#     'userid': 'ZWrgWx9o',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63382d748ceb081caa6ba997',
#     'userid': 'ZWrgWx9o',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'anqHwMQ0': [{'id': '6228777680271c3692478fc0',
#     'userid': 'anqHwMQ0',
#     'origin': '35412',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6228777680271c3692478fc0',
#     'userid': 'anqHwMQ0',
#     'origin': '39352',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0, 'Serenity': 1.6653829},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'bSuOYLw2': [{'id': '6338649a2df2fd104d686349',
#     'userid': 'bSuOYLw2',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6338649a2df2fd104d686349',
#     'userid': 'bSuOYLw2',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'btoSxy3T': [{'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f752ad16cc2ce70b6f2f',
#     'userid': 'btoSxy3T',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cBjFhvjx': [{'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39648',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 0.9177646},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cmq6JZxJ': [{'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'e4aM9WL7': [{'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.6366995},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'eLXgq0Hx': [{'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0,
#      'Disapproval': 1.0,
#      'Anger': 1.0,
#      'Anticipation': 1.8508643500000002},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '39389',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.17283429, 'Surprise': 1.0, 'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'fqybaAk8': [{'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35217',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'gD630RD1': [{'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0, 'Joy': 1.0, 'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'jTb1qXEo': [{'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35321',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35208',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Joy': 1.0, 'Trust': 1.0, 'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'lkkZ1lUv': [{'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Trust': 1.0,
#      'Serenity': 1.9848156000000001,
#      'Joy': 1.0,
#      'Surprise': 1.0,
#      'Anticipation': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Sadness': 1.7936641},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'loEoYm9R': [{'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {'Fear': 1.9968952, 'Joy': 1.0, 'Serenity': 1.0},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oITaD0ND': [{'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '39384',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.emotions',
#     'pvalue': {},
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oTT3YRMN': [{'id': '6364f959ec3ec867f01140fb',
#     'userid': 'oTT3YRMN',
#     'origin': '35364',
# ...
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'Casa',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39200',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'Sesso',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633857663f94ba59773bc667',
#     'userid': 'cBjFhvjx',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'Vecchiaia',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'cmq6JZxJ': [{'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6374b54a66be097e4b113381',
#     'userid': 'cmq6JZxJ',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'e4aM9WL7': [{'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'al mare\n\n',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '622764d6efc0335e1948a813',
#     'userid': 'e4aM9WL7',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'malattia\n',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'eLXgq0Hx': [{'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': "in trepidazione per l'attesa dell'estate, Che oggi fa troppo freddo. Che odio il freddo perchè mancano 2 giorni a Natale, Alle vacanze",
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a57d79d0c1fe512e5c7658',
#     'userid': 'eLXgq0Hx',
#     'origin': '39389',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': "felice perchè, anche se è inverno, è Natale!, il mio cane, all'interno e ai regali di Natale",
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'fqybaAk8': [{'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35380',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'un momento di relax',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6331fb30da21134eb64f76f3',
#     'userid': 'fqybaAk8',
#     'origin': '35217',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'una donna che riposa',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'gD630RD1': [{'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'un senso di nostalgia per un periodo che non ho mai vissuto. Chi sono quei due ragazzini? Cosa stanno facendo? Erano felici? Quello che resta oggi è solo un quadro (e supposizioni correlate)',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a41f59dcc2451255186b90',
#     'userid': 'gD630RD1',
#     'origin': '35571',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'cose che un tempo servivano',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'jTb1qXEo': [{'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35321',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'sola, una persona con problemi di relazione',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35208',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'gli studi del liceo, una creatura perfetta',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a43455fbfb2074534d6847',
#     'userid': 'jTb1qXEo',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'assorta, un fresco pomeriggio di aprile',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'lkkZ1lUv': [{'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35227',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'la tranquillità di una pausa pranzo durante un giorno di lavoro',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a423ac181ff6483d5b1fbd',
#     'userid': 'lkkZ1lUv',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'la stanchezza alla fine della giornata e il ritorno a casa',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'loEoYm9R': [{'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35308',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63384848f689b570b53ec481',
#     'userid': 'loEoYm9R',
#     'origin': '35310',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'sensazione di pace ed inquietudine insieme',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oITaD0ND': [{'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '39384',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'il tramonto',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a40ba99200607ab608358e',
#     'userid': 'oITaD0ND',
#     'origin': '35499',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'caldo, il caldo estivo',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'oTT3YRMN': [{'id': '6364f959ec3ec867f01140fb',
#     'userid': 'oTT3YRMN',
#     'origin': '35364',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'mia mamma perché è grazie a lei ed ai suoi insegnamenti che sono cresciuto bene ',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '6364f959ec3ec867f01140fb',
#     'userid': 'oTT3YRMN',
#     'origin': '35230',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'l’amore perché dalla mia ragazza mi sento veramente amato come ho sempre desiderato ',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'onDqgFnI': [{'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '35362',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '39416',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633856a77043f23cb5236441',
#     'userid': 'onDqgFnI',
#     'origin': '35229',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'ox8G7avH': [{'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35465',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '\nIl momento della creazione',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35256',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '\nConfuso',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633167f663cf7869106557ec',
#     'userid': 'ox8G7avH',
#     'origin': '35249',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'q2BDj1os': [{'id': '63383ea41c952b2c5e786acf',
#     'userid': 'q2BDj1os',
#     'origin': '39384',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'un aquilone in spiaggia ',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63383ea41c952b2c5e786acf',
#     'userid': 'q2BDj1os',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'due persone che fanno l’amore',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'sXKZ1IUH': [{'id': '636d08475e7e496bb86b67a1',
#     'userid': 'sXKZ1IUH',
#     'origin': '39182',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'curioso, interessato, la casa dello zio di un amico, una ragazza in attesa di qualcosa o qualcuno. Le è venuta una idea',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '636d08475e7e496bb86b67a1',
#     'userid': 'sXKZ1IUH',
#     'origin': '39138',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': "calmo, rilassato, le piscine delle terme, anche se qui c'è una barca, un ragazzo sostiene una ragazza distesa in acqua",
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'x2AUnHqw': [{'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35459',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'serenità ',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'momenti di spensieratezza',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '633848b362d1204a35295868',
#     'userid': 'x2AUnHqw',
#     'origin': '35456',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'attimi di riflessione in solitudine',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'xi3DCToA': [{'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '39175',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'la festa di Natale',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35307',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'mio paesino',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35360',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'Parigi',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63a31fe9e64e305ea45eedc6',
#     'userid': 'xi3DCToA',
#     'origin': '35381',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'Albert Camus',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'yjlouq5U': [{'id': '63385bb4f5bdab798a1a88a3',
#     'userid': 'yjlouq5U',
#     'origin': '35330',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': 'una cosa rilassante',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385bb4f5bdab798a1a88a3',
#     'userid': 'yjlouq5U',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '  ritorno a casa',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}],
#   'zZbRbDHJ': [{'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '39347',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35445',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'},
#    {'id': '63385204646abf1c883b41da',
#     'userid': 'zZbRbDHJ',
#     'origin': '35433',
#     'source_id': 'fake90e6d701748f08514b01',
#     'source': 'fake',
#     'pname': 'itMakesMeThinkAbout.text',
#     'pvalue': '',
#     'context': 'application',
#     'datapoints': 0,
#     'category': 'interest'}]}}

# %%
with open("./data/ugcContributions_merged.json", "w") as outfile:
    json.dump(newContribData, outfile, indent=2)
